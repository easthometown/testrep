# %% [markdown]
# <a href="https://colab.research.google.com/github/easthometown/testrep/blob/main/C1_W1_Lab_2_multi_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
df.head()
# Out:
#      X1     X2     X3     X4   X5  X6    X7  X8     Y1     Y2
# 0  0.71  710.5  269.5  220.5  3.5   2  0.40   5  12.43  15.59
# 1  0.69  735.0  294.0  220.5  3.5   5  0.25   5  12.47  14.60
# 2  0.62  808.5  367.5  220.5  3.5   2  0.40   2  16.76  17.36
# 3  0.86  588.0  294.0  147.0  7.0   3  0.10   4  25.37  31.76
# 4  0.86  588.0  294.0  147.0  7.0   2  0.40   3  31.28  35.22

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 260.5758 - y1_output_loss: 123.0935 - y2_output_loss: 139.6149 - y1_output_root_mean_squared_error: 11.0855 - y2_output_root_mean_squared_error: 11.7340 - val_loss: 192.9684 - val_y1_output_loss: 48.5242 - val_y2_output_loss: 142.3737 - val_y1_output_root_mean_squared_error: 7.0107 - val_y2_output_root_mean_squared_error: 11.9925
# Epoch 2/500
# 614/614 [==============================] - 0s 175us/sample - loss: 43.1129 - y1_output_loss: 15.4931 - y2_output_loss: 28.8601 - y1_output_root_mean_squared_error: 3.9224 - y2_output_root_mean_squared_error: 5.2657 - val_loss: 284.4852 - val_y1_output_loss: 58.2527 - val_y2_output_loss: 230.9634 - val_y1_output_root_mean_squared_error: 7.5160 - val_y2_output_root_mean_squared_error: 15.0995
# Epoch 3/500
# 614/614 [==============================] - 0s 163us/sample - loss: 31.8310 - y1_output_loss: 11.8014 - y2_output_loss: 20.1464 - y1_output_root_mean_squared_error: 3.4106 - y2_output_root_mean_squared_error: 4.4943 - val_loss: 30.7072 - val_y1_output_loss: 12.6326 - val_y2_output_loss: 17.3030 - val_y1_output_root_mean_squared_error: 3.5937 - val_y2_output_root_mean_squared_error: 4.2182
# Epoch 4/500
# 614/614 [==============================] - 0s 157us/sample - loss: 26.1558 - y1_output_loss: 10.7314 - y2_output_loss: 16.8839 - y1_output_root_mean_squared_error: 3.2309 - y2_output_root_mean_squared_error: 3.9644 - val_loss: 203.9526 - val_y1_output_loss: 25.3380 - val_y2_output_loss: 175.8431 - val_y1_output_root_mean_squared_error: 5.0933 - val_y2_output_root_mean_squared_error: 13.3421
# Epoch 5/500
# 614/614 [==============================] - 0s 164us/sample - loss: 35.2634 - y1_output_loss: 11.6710 - y2_output_loss: 24.3532 - y1_output_root_mean_squared_error: 3.3691 - y2_output_root_mean_squared_error: 4.8901 - val_loss: 79.2786 - val_y1_output_loss: 16.1474 - val_y2_output_loss: 61.6199 - val_y1_output_root_mean_squared_error: 4.0678 - val_y2_output_root_mean_squared_error: 7.9204
# Epoch 6/500
# 614/614 [==============================] - 0s 174us/sample - loss: 26.0098 - y1_output_loss: 9.7046 - y2_output_loss: 16.1759 - y1_output_root_mean_squared_error: 3.1233 - y2_output_root_mean_squared_error: 4.0317 - val_loss: 17.9378 - val_y1_output_loss: 7.6204 - val_y2_output_loss: 10.5590 - val_y1_output_root_mean_squared_error: 2.7384 - val_y2_output_root_mean_squared_error: 3.2309
# Epoch 7/500
# 614/614 [==============================] - 0s 156us/sample - loss: 24.3390 - y1_output_loss: 9.2773 - y2_output_loss: 15.2258 - y1_output_root_mean_squared_error: 3.0418 - y2_output_root_mean_squared_error: 3.8841 - val_loss: 68.8121 - val_y1_output_loss: 18.7710 - val_y2_output_loss: 52.5631 - val_y1_output_root_mean_squared_error: 4.2078 - val_y2_output_root_mean_squared_error: 7.1489
# Epoch 8/500
# 614/614 [==============================] - 0s 162us/sample - loss: 20.5922 - y1_output_loss: 8.2183 - y2_output_loss: 12.3359 - y1_output_root_mean_squared_error: 2.8760 - y2_output_root_mean_squared_error: 3.5101 - val_loss: 42.5671 - val_y1_output_loss: 10.7695 - val_y2_output_loss: 33.1551 - val_y1_output_root_mean_squared_error: 3.1943 - val_y2_output_root_mean_squared_error: 5.6889
# Epoch 9/500
# 614/614 [==============================] - 0s 159us/sample - loss: 22.6401 - y1_output_loss: 8.7557 - y2_output_loss: 13.7160 - y1_output_root_mean_squared_error: 2.9698 - y2_output_root_mean_squared_error: 3.7176 - val_loss: 29.9152 - val_y1_output_loss: 9.6490 - val_y2_output_loss: 21.3862 - val_y1_output_root_mean_squared_error: 3.0221 - val_y2_output_root_mean_squared_error: 4.5587
# Epoch 10/500
# 614/614 [==============================] - 0s 157us/sample - loss: 19.3350 - y1_output_loss: 8.1737 - y2_output_loss: 11.2866 - y1_output_root_mean_squared_error: 2.8406 - y2_output_root_mean_squared_error: 3.3565 - val_loss: 15.0119 - val_y1_output_loss: 6.4204 - val_y2_output_loss: 8.7741 - val_y1_output_root_mean_squared_error: 2.5076 - val_y2_output_root_mean_squared_error: 2.9536
# Epoch 11/500
# 614/614 [==============================] - 0s 157us/sample - loss: 20.6011 - y1_output_loss: 8.3259 - y2_output_loss: 12.5562 - y1_output_root_mean_squared_error: 2.8865 - y2_output_root_mean_squared_error: 3.5027 - val_loss: 24.1732 - val_y1_output_loss: 7.2390 - val_y2_output_loss: 16.3501 - val_y1_output_root_mean_squared_error: 2.7214 - val_y2_output_root_mean_squared_error: 4.0948
# Epoch 12/500
# 614/614 [==============================] - 0s 159us/sample - loss: 22.2502 - y1_output_loss: 8.6956 - y2_output_loss: 13.3978 - y1_output_root_mean_squared_error: 2.9610 - y2_output_root_mean_squared_error: 3.6719 - val_loss: 14.0033 - val_y1_output_loss: 5.9823 - val_y2_output_loss: 8.2552 - val_y1_output_root_mean_squared_error: 2.3947 - val_y2_output_root_mean_squared_error: 2.8755
# Epoch 13/500
# 614/614 [==============================] - 0s 173us/sample - loss: 19.1228 - y1_output_loss: 7.7898 - y2_output_loss: 11.3612 - y1_output_root_mean_squared_error: 2.7857 - y2_output_root_mean_squared_error: 3.3709 - val_loss: 29.0875 - val_y1_output_loss: 7.7089 - val_y2_output_loss: 22.0299 - val_y1_output_root_mean_squared_error: 2.7263 - val_y2_output_root_mean_squared_error: 4.6535
# Epoch 14/500
# 614/614 [==============================] - 0s 172us/sample - loss: 18.1097 - y1_output_loss: 7.5845 - y2_output_loss: 10.4833 - y1_output_root_mean_squared_error: 2.7516 - y2_output_root_mean_squared_error: 3.2463 - val_loss: 18.4835 - val_y1_output_loss: 8.1951 - val_y2_output_loss: 10.5863 - val_y1_output_root_mean_squared_error: 2.8146 - val_y2_output_root_mean_squared_error: 3.2498
# Epoch 15/500
# 614/614 [==============================] - 0s 160us/sample - loss: 20.6983 - y1_output_loss: 8.0480 - y2_output_loss: 12.5013 - y1_output_root_mean_squared_error: 2.8489 - y2_output_root_mean_squared_error: 3.5471 - val_loss: 13.1044 - val_y1_output_loss: 5.7062 - val_y2_output_loss: 7.6831 - val_y1_output_root_mean_squared_error: 2.3284 - val_y2_output_root_mean_squared_error: 2.7718
# Epoch 16/500
# 614/614 [==============================] - 0s 169us/sample - loss: 17.2094 - y1_output_loss: 6.7755 - y2_output_loss: 10.3121 - y1_output_root_mean_squared_error: 2.6125 - y2_output_root_mean_squared_error: 3.2225 - val_loss: 13.6632 - val_y1_output_loss: 5.8515 - val_y2_output_loss: 8.1717 - val_y1_output_root_mean_squared_error: 2.3636 - val_y2_output_root_mean_squared_error: 2.8420
# Epoch 17/500
# 614/614 [==============================] - 0s 159us/sample - loss: 21.7302 - y1_output_loss: 7.8968 - y2_output_loss: 13.7754 - y1_output_root_mean_squared_error: 2.8148 - y2_output_root_mean_squared_error: 3.7158 - val_loss: 33.5059 - val_y1_output_loss: 11.0454 - val_y2_output_loss: 23.1271 - val_y1_output_root_mean_squared_error: 3.2725 - val_y2_output_root_mean_squared_error: 4.7746
# Epoch 18/500
# 614/614 [==============================] - 0s 161us/sample - loss: 17.9533 - y1_output_loss: 7.1142 - y2_output_loss: 10.7570 - y1_output_root_mean_squared_error: 2.6759 - y2_output_root_mean_squared_error: 3.2853 - val_loss: 19.5766 - val_y1_output_loss: 5.7992 - val_y2_output_loss: 14.3221 - val_y1_output_root_mean_squared_error: 2.3582 - val_y2_output_root_mean_squared_error: 3.7437
# Epoch 19/500
# 614/614 [==============================] - 0s 157us/sample - loss: 16.4816 - y1_output_loss: 6.5615 - y2_output_loss: 9.8623 - y1_output_root_mean_squared_error: 2.5685 - y2_output_root_mean_squared_error: 3.1440 - val_loss: 28.9108 - val_y1_output_loss: 9.4632 - val_y2_output_loss: 20.0999 - val_y1_output_root_mean_squared_error: 3.0251 - val_y2_output_root_mean_squared_error: 4.4452
# Epoch 20/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.7230 - y1_output_loss: 6.3609 - y2_output_loss: 9.2663 - y1_output_root_mean_squared_error: 2.5292 - y2_output_root_mean_squared_error: 3.0539 - val_loss: 10.7080 - val_y1_output_loss: 4.3220 - val_y2_output_loss: 6.4556 - val_y1_output_root_mean_squared_error: 2.0517 - val_y2_output_root_mean_squared_error: 2.5492
# Epoch 21/500
# 614/614 [==============================] - 0s 156us/sample - loss: 15.6582 - y1_output_loss: 6.0443 - y2_output_loss: 9.5917 - y1_output_root_mean_squared_error: 2.4685 - y2_output_root_mean_squared_error: 3.0927 - val_loss: 15.3172 - val_y1_output_loss: 4.7660 - val_y2_output_loss: 10.2294 - val_y1_output_root_mean_squared_error: 2.1969 - val_y2_output_root_mean_squared_error: 3.2390
# Epoch 22/500
# 614/614 [==============================] - 0s 180us/sample - loss: 13.0084 - y1_output_loss: 5.5430 - y2_output_loss: 7.3970 - y1_output_root_mean_squared_error: 2.3600 - y2_output_root_mean_squared_error: 2.7274 - val_loss: 13.5781 - val_y1_output_loss: 4.5007 - val_y2_output_loss: 9.3968 - val_y1_output_root_mean_squared_error: 2.0783 - val_y2_output_root_mean_squared_error: 3.0428
# Epoch 23/500
# 614/614 [==============================] - 0s 166us/sample - loss: 16.9789 - y1_output_loss: 6.4483 - y2_output_loss: 10.4257 - y1_output_root_mean_squared_error: 2.5462 - y2_output_root_mean_squared_error: 3.2397 - val_loss: 13.5295 - val_y1_output_loss: 3.2301 - val_y2_output_loss: 10.3740 - val_y1_output_root_mean_squared_error: 1.7936 - val_y2_output_root_mean_squared_error: 3.2113
# Epoch 24/500
# 614/614 [==============================] - 0s 154us/sample - loss: 14.4476 - y1_output_loss: 5.3990 - y2_output_loss: 8.9457 - y1_output_root_mean_squared_error: 2.3329 - y2_output_root_mean_squared_error: 3.0008 - val_loss: 10.9085 - val_y1_output_loss: 3.2677 - val_y2_output_loss: 7.4994 - val_y1_output_root_mean_squared_error: 1.8038 - val_y2_output_root_mean_squared_error: 2.7667
# Epoch 25/500
# 614/614 [==============================] - 0s 156us/sample - loss: 12.8338 - y1_output_loss: 5.1399 - y2_output_loss: 7.6799 - y1_output_root_mean_squared_error: 2.2652 - y2_output_root_mean_squared_error: 2.7754 - val_loss: 11.9467 - val_y1_output_loss: 4.1577 - val_y2_output_loss: 8.0403 - val_y1_output_root_mean_squared_error: 1.9930 - val_y2_output_root_mean_squared_error: 2.8240
# Epoch 26/500
# 614/614 [==============================] - 0s 163us/sample - loss: 11.7301 - y1_output_loss: 4.7346 - y2_output_loss: 7.0110 - y1_output_root_mean_squared_error: 2.1629 - y2_output_root_mean_squared_error: 2.6555 - val_loss: 9.1453 - val_y1_output_loss: 3.1008 - val_y2_output_loss: 6.1035 - val_y1_output_root_mean_squared_error: 1.7425 - val_y2_output_root_mean_squared_error: 2.4716
# Epoch 27/500
# 614/614 [==============================] - 0s 160us/sample - loss: 13.3754 - y1_output_loss: 4.9146 - y2_output_loss: 8.4338 - y1_output_root_mean_squared_error: 2.2256 - y2_output_root_mean_squared_error: 2.9021 - val_loss: 8.4702 - val_y1_output_loss: 2.7773 - val_y2_output_loss: 5.6600 - val_y1_output_root_mean_squared_error: 1.6598 - val_y2_output_root_mean_squared_error: 2.3907
# Epoch 28/500
# 614/614 [==============================] - 0s 160us/sample - loss: 14.6671 - y1_output_loss: 5.2049 - y2_output_loss: 9.3993 - y1_output_root_mean_squared_error: 2.2767 - y2_output_root_mean_squared_error: 3.0795 - val_loss: 20.8218 - val_y1_output_loss: 7.3907 - val_y2_output_loss: 13.6155 - val_y1_output_root_mean_squared_error: 2.6973 - val_y2_output_root_mean_squared_error: 3.6805
# Epoch 29/500
# 614/614 [==============================] - 0s 158us/sample - loss: 11.3715 - y1_output_loss: 4.2930 - y2_output_loss: 6.9935 - y1_output_root_mean_squared_error: 2.0803 - y2_output_root_mean_squared_error: 2.6541 - val_loss: 7.5919 - val_y1_output_loss: 2.6185 - val_y2_output_loss: 5.0937 - val_y1_output_root_mean_squared_error: 1.5954 - val_y2_output_root_mean_squared_error: 2.2465
# Epoch 30/500
# 614/614 [==============================] - 0s 246us/sample - loss: 10.9901 - y1_output_loss: 4.3322 - y2_output_loss: 6.7162 - y1_output_root_mean_squared_error: 2.0736 - y2_output_root_mean_squared_error: 2.5866 - val_loss: 31.9271 - val_y1_output_loss: 8.0228 - val_y2_output_loss: 24.4601 - val_y1_output_root_mean_squared_error: 2.7927 - val_y2_output_root_mean_squared_error: 4.9120
# Epoch 31/500
# 614/614 [==============================] - 0s 171us/sample - loss: 10.2968 - y1_output_loss: 3.6738 - y2_output_loss: 6.5791 - y1_output_root_mean_squared_error: 1.9209 - y2_output_root_mean_squared_error: 2.5704 - val_loss: 13.0045 - val_y1_output_loss: 4.5276 - val_y2_output_loss: 8.3301 - val_y1_output_root_mean_squared_error: 2.1497 - val_y2_output_root_mean_squared_error: 2.8954
# Epoch 32/500
# 614/614 [==============================] - 0s 160us/sample - loss: 9.0933 - y1_output_loss: 3.4195 - y2_output_loss: 5.7285 - y1_output_root_mean_squared_error: 1.8543 - y2_output_root_mean_squared_error: 2.3780 - val_loss: 21.8266 - val_y1_output_loss: 3.4597 - val_y2_output_loss: 18.4030 - val_y1_output_root_mean_squared_error: 1.8890 - val_y2_output_root_mean_squared_error: 4.2729
# Epoch 33/500
# 614/614 [==============================] - 0s 167us/sample - loss: 14.6677 - y1_output_loss: 4.4846 - y2_output_loss: 10.0436 - y1_output_root_mean_squared_error: 2.1278 - y2_output_root_mean_squared_error: 3.1844 - val_loss: 6.7742 - val_y1_output_loss: 1.9534 - val_y2_output_loss: 4.8419 - val_y1_output_root_mean_squared_error: 1.4035 - val_y2_output_root_mean_squared_error: 2.1919
# Epoch 34/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.7036 - y1_output_loss: 3.8199 - y2_output_loss: 6.9010 - y1_output_root_mean_squared_error: 1.9569 - y2_output_root_mean_squared_error: 2.6218 - val_loss: 10.2343 - val_y1_output_loss: 2.7508 - val_y2_output_loss: 7.5041 - val_y1_output_root_mean_squared_error: 1.6877 - val_y2_output_root_mean_squared_error: 2.7177
# Epoch 35/500
# 614/614 [==============================] - 0s 159us/sample - loss: 8.3870 - y1_output_loss: 3.1248 - y2_output_loss: 5.3190 - y1_output_root_mean_squared_error: 1.7525 - y2_output_root_mean_squared_error: 2.3056 - val_loss: 6.8485 - val_y1_output_loss: 1.9671 - val_y2_output_loss: 4.9320 - val_y1_output_root_mean_squared_error: 1.4135 - val_y2_output_root_mean_squared_error: 2.2024
# Epoch 36/500
# 614/614 [==============================] - 0s 158us/sample - loss: 8.6402 - y1_output_loss: 3.0637 - y2_output_loss: 5.5553 - y1_output_root_mean_squared_error: 1.7543 - y2_output_root_mean_squared_error: 2.3585 - val_loss: 11.1993 - val_y1_output_loss: 3.1879 - val_y2_output_loss: 8.0074 - val_y1_output_root_mean_squared_error: 1.8111 - val_y2_output_root_mean_squared_error: 2.8141
# Epoch 37/500
# 614/614 [==============================] - 0s 163us/sample - loss: 10.6018 - y1_output_loss: 3.6369 - y2_output_loss: 6.9521 - y1_output_root_mean_squared_error: 1.9046 - y2_output_root_mean_squared_error: 2.6409 - val_loss: 15.2847 - val_y1_output_loss: 4.1069 - val_y2_output_loss: 11.6507 - val_y1_output_root_mean_squared_error: 1.9867 - val_y2_output_root_mean_squared_error: 3.3671
# Epoch 38/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.5631 - y1_output_loss: 3.0854 - y2_output_loss: 5.4788 - y1_output_root_mean_squared_error: 1.7548 - y2_output_root_mean_squared_error: 2.3417 - val_loss: 11.6529 - val_y1_output_loss: 2.1679 - val_y2_output_loss: 9.7720 - val_y1_output_root_mean_squared_error: 1.4586 - val_y2_output_root_mean_squared_error: 3.0863
# Epoch 39/500
# 614/614 [==============================] - 0s 156us/sample - loss: 7.2377 - y1_output_loss: 2.6663 - y2_output_loss: 4.5819 - y1_output_root_mean_squared_error: 1.6344 - y2_output_root_mean_squared_error: 2.1369 - val_loss: 7.0623 - val_y1_output_loss: 2.1356 - val_y2_output_loss: 5.0476 - val_y1_output_root_mean_squared_error: 1.4715 - val_y2_output_root_mean_squared_error: 2.2129
# Epoch 40/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.8748 - y1_output_loss: 2.3866 - y2_output_loss: 4.4482 - y1_output_root_mean_squared_error: 1.5468 - y2_output_root_mean_squared_error: 2.1171 - val_loss: 10.2267 - val_y1_output_loss: 3.7161 - val_y2_output_loss: 6.9048 - val_y1_output_root_mean_squared_error: 1.8921 - val_y2_output_root_mean_squared_error: 2.5781
# Epoch 41/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.7332 - y1_output_loss: 2.4492 - y2_output_loss: 5.2900 - y1_output_root_mean_squared_error: 1.5689 - y2_output_root_mean_squared_error: 2.2960 - val_loss: 6.7226 - val_y1_output_loss: 1.5696 - val_y2_output_loss: 5.3998 - val_y1_output_root_mean_squared_error: 1.2573 - val_y2_output_root_mean_squared_error: 2.2675
# Epoch 42/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.3350 - y1_output_loss: 2.4850 - y2_output_loss: 4.8739 - y1_output_root_mean_squared_error: 1.5673 - y2_output_root_mean_squared_error: 2.2088 - val_loss: 6.0511 - val_y1_output_loss: 1.9401 - val_y2_output_loss: 4.2153 - val_y1_output_root_mean_squared_error: 1.3920 - val_y2_output_root_mean_squared_error: 2.0282
# Epoch 43/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.9040 - y1_output_loss: 2.8592 - y2_output_loss: 6.0741 - y1_output_root_mean_squared_error: 1.6861 - y2_output_root_mean_squared_error: 2.4619 - val_loss: 7.0106 - val_y1_output_loss: 2.2737 - val_y2_output_loss: 4.7941 - val_y1_output_root_mean_squared_error: 1.5237 - val_y2_output_root_mean_squared_error: 2.1654
# Epoch 44/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.3766 - y1_output_loss: 2.7328 - y2_output_loss: 5.7071 - y1_output_root_mean_squared_error: 1.6528 - y2_output_root_mean_squared_error: 2.3759 - val_loss: 7.3273 - val_y1_output_loss: 2.0654 - val_y2_output_loss: 5.3783 - val_y1_output_root_mean_squared_error: 1.4629 - val_y2_output_root_mean_squared_error: 2.2775
# Epoch 45/500
# 614/614 [==============================] - 0s 154us/sample - loss: 9.8821 - y1_output_loss: 3.2869 - y2_output_loss: 6.5271 - y1_output_root_mean_squared_error: 1.8177 - y2_output_root_mean_squared_error: 2.5647 - val_loss: 9.0072 - val_y1_output_loss: 2.2861 - val_y2_output_loss: 7.0499 - val_y1_output_root_mean_squared_error: 1.4855 - val_y2_output_root_mean_squared_error: 2.6078
# Epoch 46/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.3844 - y1_output_loss: 2.6938 - y2_output_loss: 5.6747 - y1_output_root_mean_squared_error: 1.6457 - y2_output_root_mean_squared_error: 2.3825 - val_loss: 5.4584 - val_y1_output_loss: 1.5330 - val_y2_output_loss: 4.0565 - val_y1_output_root_mean_squared_error: 1.2524 - val_y2_output_root_mean_squared_error: 1.9723
# Epoch 47/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.5026 - y1_output_loss: 2.5793 - y2_output_loss: 4.8845 - y1_output_root_mean_squared_error: 1.6056 - y2_output_root_mean_squared_error: 2.2192 - val_loss: 5.0398 - val_y1_output_loss: 1.3636 - val_y2_output_loss: 3.8204 - val_y1_output_root_mean_squared_error: 1.1742 - val_y2_output_root_mean_squared_error: 1.9134
# Epoch 48/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.3523 - y1_output_loss: 2.4942 - y2_output_loss: 5.8664 - y1_output_root_mean_squared_error: 1.5809 - y2_output_root_mean_squared_error: 2.4193 - val_loss: 5.8731 - val_y1_output_loss: 1.7148 - val_y2_output_loss: 4.3003 - val_y1_output_root_mean_squared_error: 1.3014 - val_y2_output_root_mean_squared_error: 2.0444
# Epoch 49/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.7490 - y1_output_loss: 2.2441 - y2_output_loss: 4.4763 - y1_output_root_mean_squared_error: 1.4959 - y2_output_root_mean_squared_error: 2.1240 - val_loss: 12.5088 - val_y1_output_loss: 4.8886 - val_y2_output_loss: 8.1210 - val_y1_output_root_mean_squared_error: 2.1670 - val_y2_output_root_mean_squared_error: 2.7952
# Epoch 50/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.9095 - y1_output_loss: 2.0104 - y2_output_loss: 4.8804 - y1_output_root_mean_squared_error: 1.4188 - y2_output_root_mean_squared_error: 2.2128 - val_loss: 5.3258 - val_y1_output_loss: 1.6327 - val_y2_output_loss: 3.9233 - val_y1_output_root_mean_squared_error: 1.2567 - val_y2_output_root_mean_squared_error: 1.9356
# Epoch 51/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.7199 - y1_output_loss: 2.1782 - y2_output_loss: 4.6196 - y1_output_root_mean_squared_error: 1.4541 - y2_output_root_mean_squared_error: 2.1460 - val_loss: 11.6809 - val_y1_output_loss: 3.6915 - val_y2_output_loss: 8.0036 - val_y1_output_root_mean_squared_error: 1.9558 - val_y2_output_root_mean_squared_error: 2.8028
# Epoch 52/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.3170 - y1_output_loss: 2.1177 - y2_output_loss: 5.2674 - y1_output_root_mean_squared_error: 1.4426 - y2_output_root_mean_squared_error: 2.2882 - val_loss: 10.0686 - val_y1_output_loss: 3.1916 - val_y2_output_loss: 6.9435 - val_y1_output_root_mean_squared_error: 1.8141 - val_y2_output_root_mean_squared_error: 2.6034
# Epoch 53/500
# 614/614 [==============================] - 0s 156us/sample - loss: 7.9725 - y1_output_loss: 2.4779 - y2_output_loss: 5.5655 - y1_output_root_mean_squared_error: 1.5649 - y2_output_root_mean_squared_error: 2.3502 - val_loss: 25.6048 - val_y1_output_loss: 7.9143 - val_y2_output_loss: 18.3414 - val_y1_output_root_mean_squared_error: 2.7736 - val_y2_output_root_mean_squared_error: 4.2322
# Epoch 54/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.9487 - y1_output_loss: 2.1613 - y2_output_loss: 4.8186 - y1_output_root_mean_squared_error: 1.4602 - y2_output_root_mean_squared_error: 2.1947 - val_loss: 18.0085 - val_y1_output_loss: 4.2921 - val_y2_output_loss: 14.3229 - val_y1_output_root_mean_squared_error: 2.0230 - val_y2_output_root_mean_squared_error: 3.7304
# Epoch 55/500
# 614/614 [==============================] - 0s 159us/sample - loss: 8.7674 - y1_output_loss: 2.7088 - y2_output_loss: 6.0138 - y1_output_root_mean_squared_error: 1.6520 - y2_output_root_mean_squared_error: 2.4573 - val_loss: 5.8313 - val_y1_output_loss: 1.7568 - val_y2_output_loss: 4.3461 - val_y1_output_root_mean_squared_error: 1.3128 - val_y2_output_root_mean_squared_error: 2.0268
# Epoch 56/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.1328 - y1_output_loss: 1.9575 - y2_output_loss: 4.1504 - y1_output_root_mean_squared_error: 1.4032 - y2_output_root_mean_squared_error: 2.0405 - val_loss: 5.7608 - val_y1_output_loss: 1.3955 - val_y2_output_loss: 4.5499 - val_y1_output_root_mean_squared_error: 1.1917 - val_y2_output_root_mean_squared_error: 2.0834
# Epoch 57/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.8165 - y1_output_loss: 2.8124 - y2_output_loss: 5.9897 - y1_output_root_mean_squared_error: 1.6825 - y2_output_root_mean_squared_error: 2.4466 - val_loss: 7.6152 - val_y1_output_loss: 1.1730 - val_y2_output_loss: 6.6351 - val_y1_output_root_mean_squared_error: 1.0891 - val_y2_output_root_mean_squared_error: 2.5355
# Epoch 58/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8239 - y1_output_loss: 1.7709 - y2_output_loss: 4.0111 - y1_output_root_mean_squared_error: 1.3355 - y2_output_root_mean_squared_error: 2.0101 - val_loss: 9.8656 - val_y1_output_loss: 1.5333 - val_y2_output_loss: 8.7099 - val_y1_output_root_mean_squared_error: 1.2176 - val_y2_output_root_mean_squared_error: 2.8953
# Epoch 59/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.9227 - y1_output_loss: 1.7789 - y2_output_loss: 4.1335 - y1_output_root_mean_squared_error: 1.3319 - y2_output_root_mean_squared_error: 2.0368 - val_loss: 6.7874 - val_y1_output_loss: 1.8912 - val_y2_output_loss: 5.1784 - val_y1_output_root_mean_squared_error: 1.3600 - val_y2_output_root_mean_squared_error: 2.2221
# Epoch 60/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.1976 - y1_output_loss: 2.7184 - y2_output_loss: 5.4315 - y1_output_root_mean_squared_error: 1.6541 - y2_output_root_mean_squared_error: 2.3370 - val_loss: 6.4952 - val_y1_output_loss: 1.3928 - val_y2_output_loss: 5.2823 - val_y1_output_root_mean_squared_error: 1.1732 - val_y2_output_root_mean_squared_error: 2.2625
# Epoch 61/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.8365 - y1_output_loss: 2.0982 - y2_output_loss: 4.9070 - y1_output_root_mean_squared_error: 1.4474 - y2_output_root_mean_squared_error: 2.1775 - val_loss: 23.5908 - val_y1_output_loss: 5.8977 - val_y2_output_loss: 17.4330 - val_y1_output_root_mean_squared_error: 2.4720 - val_y2_output_root_mean_squared_error: 4.1809
# Epoch 62/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.7116 - y1_output_loss: 1.6220 - y2_output_loss: 4.0961 - y1_output_root_mean_squared_error: 1.2700 - y2_output_root_mean_squared_error: 2.0245 - val_loss: 5.4570 - val_y1_output_loss: 1.7921 - val_y2_output_loss: 3.9326 - val_y1_output_root_mean_squared_error: 1.3156 - val_y2_output_root_mean_squared_error: 1.9304
# Epoch 63/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.0849 - y1_output_loss: 1.3476 - y2_output_loss: 3.8136 - y1_output_root_mean_squared_error: 1.1633 - y2_output_root_mean_squared_error: 1.9317 - val_loss: 22.2115 - val_y1_output_loss: 4.2934 - val_y2_output_loss: 18.3431 - val_y1_output_root_mean_squared_error: 2.0485 - val_y2_output_root_mean_squared_error: 4.2444
# Epoch 64/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.7658 - y1_output_loss: 1.6197 - y2_output_loss: 4.1103 - y1_output_root_mean_squared_error: 1.2760 - y2_output_root_mean_squared_error: 2.0341 - val_loss: 8.0610 - val_y1_output_loss: 2.1283 - val_y2_output_loss: 6.1829 - val_y1_output_root_mean_squared_error: 1.4421 - val_y2_output_root_mean_squared_error: 2.4457
# Epoch 65/500
# 614/614 [==============================] - 0s 155us/sample - loss: 6.2912 - y1_output_loss: 1.9488 - y2_output_loss: 4.3759 - y1_output_root_mean_squared_error: 1.3970 - y2_output_root_mean_squared_error: 2.0832 - val_loss: 22.3577 - val_y1_output_loss: 8.3964 - val_y2_output_loss: 13.4332 - val_y1_output_root_mean_squared_error: 2.9521 - val_y2_output_root_mean_squared_error: 3.6936
# Epoch 66/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.7715 - y1_output_loss: 2.5673 - y2_output_loss: 6.1674 - y1_output_root_mean_squared_error: 1.6028 - y2_output_root_mean_squared_error: 2.4905 - val_loss: 4.7367 - val_y1_output_loss: 1.1008 - val_y2_output_loss: 3.8384 - val_y1_output_root_mean_squared_error: 1.0403 - val_y2_output_root_mean_squared_error: 1.9117
# Epoch 67/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.6216 - y1_output_loss: 1.8427 - y2_output_loss: 4.7207 - y1_output_root_mean_squared_error: 1.3635 - y2_output_root_mean_squared_error: 2.1823 - val_loss: 4.1636 - val_y1_output_loss: 0.6981 - val_y2_output_loss: 3.6048 - val_y1_output_root_mean_squared_error: 0.8400 - val_y2_output_root_mean_squared_error: 1.8596
# Epoch 68/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.8624 - y1_output_loss: 1.2249 - y2_output_loss: 3.7523 - y1_output_root_mean_squared_error: 1.1039 - y2_output_root_mean_squared_error: 1.9089 - val_loss: 29.4135 - val_y1_output_loss: 4.8958 - val_y2_output_loss: 24.7987 - val_y1_output_root_mean_squared_error: 2.1968 - val_y2_output_root_mean_squared_error: 4.9586
# Epoch 69/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.9285 - y1_output_loss: 1.3151 - y2_output_loss: 3.5834 - y1_output_root_mean_squared_error: 1.1490 - y2_output_root_mean_squared_error: 1.8996 - val_loss: 4.6058 - val_y1_output_loss: 0.9893 - val_y2_output_loss: 3.8521 - val_y1_output_root_mean_squared_error: 0.9724 - val_y2_output_root_mean_squared_error: 1.9132
# Epoch 70/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.0239 - y1_output_loss: 0.9780 - y2_output_loss: 3.0505 - y1_output_root_mean_squared_error: 0.9919 - y2_output_root_mean_squared_error: 1.7435 - val_loss: 8.3641 - val_y1_output_loss: 1.9513 - val_y2_output_loss: 6.6726 - val_y1_output_root_mean_squared_error: 1.3848 - val_y2_output_root_mean_squared_error: 2.5390
# Epoch 71/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.3603 - y1_output_loss: 0.9925 - y2_output_loss: 3.3397 - y1_output_root_mean_squared_error: 1.0008 - y2_output_root_mean_squared_error: 1.8327 - val_loss: 6.6720 - val_y1_output_loss: 1.5537 - val_y2_output_loss: 5.3286 - val_y1_output_root_mean_squared_error: 1.2271 - val_y2_output_root_mean_squared_error: 2.2729
# Epoch 72/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.5444 - y1_output_loss: 1.1353 - y2_output_loss: 3.3755 - y1_output_root_mean_squared_error: 1.0698 - y2_output_root_mean_squared_error: 1.8439 - val_loss: 6.0805 - val_y1_output_loss: 1.2376 - val_y2_output_loss: 5.0730 - val_y1_output_root_mean_squared_error: 1.0824 - val_y2_output_root_mean_squared_error: 2.2156
# Epoch 73/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.9969 - y1_output_loss: 0.9199 - y2_output_loss: 3.0638 - y1_output_root_mean_squared_error: 0.9616 - y2_output_root_mean_squared_error: 1.7528 - val_loss: 3.2707 - val_y1_output_loss: 0.6127 - val_y2_output_loss: 2.8054 - val_y1_output_root_mean_squared_error: 0.7725 - val_y2_output_root_mean_squared_error: 1.6352
# Epoch 74/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.4904 - y1_output_loss: 1.3920 - y2_output_loss: 4.3676 - y1_output_root_mean_squared_error: 1.1682 - y2_output_root_mean_squared_error: 2.0312 - val_loss: 17.4254 - val_y1_output_loss: 4.5382 - val_y2_output_loss: 12.6301 - val_y1_output_root_mean_squared_error: 2.1635 - val_y2_output_root_mean_squared_error: 3.5699
# Epoch 75/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.0284 - y1_output_loss: 0.9885 - y2_output_loss: 3.0196 - y1_output_root_mean_squared_error: 0.9965 - y2_output_root_mean_squared_error: 1.7422 - val_loss: 5.2294 - val_y1_output_loss: 0.7000 - val_y2_output_loss: 4.7204 - val_y1_output_root_mean_squared_error: 0.8122 - val_y2_output_root_mean_squared_error: 2.1377
# Epoch 76/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.8378 - y1_output_loss: 1.6106 - y2_output_loss: 4.2014 - y1_output_root_mean_squared_error: 1.2693 - y2_output_root_mean_squared_error: 2.0559 - val_loss: 4.3301 - val_y1_output_loss: 0.9037 - val_y2_output_loss: 3.6268 - val_y1_output_root_mean_squared_error: 0.9394 - val_y2_output_root_mean_squared_error: 1.8568
# Epoch 77/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.5017 - y1_output_loss: 0.8334 - y2_output_loss: 2.6688 - y1_output_root_mean_squared_error: 0.9132 - y2_output_root_mean_squared_error: 1.6334 - val_loss: 5.3308 - val_y1_output_loss: 1.3959 - val_y2_output_loss: 3.9778 - val_y1_output_root_mean_squared_error: 1.1955 - val_y2_output_root_mean_squared_error: 1.9753
# Epoch 78/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.5562 - y1_output_loss: 0.8687 - y2_output_loss: 2.6788 - y1_output_root_mean_squared_error: 0.9235 - y2_output_root_mean_squared_error: 1.6442 - val_loss: 2.9429 - val_y1_output_loss: 0.5139 - val_y2_output_loss: 2.5430 - val_y1_output_root_mean_squared_error: 0.7145 - val_y2_output_root_mean_squared_error: 1.5596
# Epoch 79/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.7914 - y1_output_loss: 0.9187 - y2_output_loss: 2.8603 - y1_output_root_mean_squared_error: 0.9605 - y2_output_root_mean_squared_error: 1.6938 - val_loss: 4.8648 - val_y1_output_loss: 0.9384 - val_y2_output_loss: 3.9957 - val_y1_output_root_mean_squared_error: 0.9853 - val_y2_output_root_mean_squared_error: 1.9733
# Epoch 80/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.2500 - y1_output_loss: 0.7031 - y2_output_loss: 2.5606 - y1_output_root_mean_squared_error: 0.8405 - y2_output_root_mean_squared_error: 1.5949 - val_loss: 3.0973 - val_y1_output_loss: 0.6632 - val_y2_output_loss: 2.5127 - val_y1_output_root_mean_squared_error: 0.8168 - val_y2_output_root_mean_squared_error: 1.5589
# Epoch 81/500
# 614/614 [==============================] - 0s 211us/sample - loss: 3.2780 - y1_output_loss: 0.7082 - y2_output_loss: 2.6113 - y1_output_root_mean_squared_error: 0.8428 - y2_output_root_mean_squared_error: 1.6024 - val_loss: 12.4925 - val_y1_output_loss: 1.9087 - val_y2_output_loss: 10.8777 - val_y1_output_root_mean_squared_error: 1.3569 - val_y2_output_root_mean_squared_error: 3.2636
# Epoch 82/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.1061 - y1_output_loss: 0.6563 - y2_output_loss: 2.4285 - y1_output_root_mean_squared_error: 0.8115 - y2_output_root_mean_squared_error: 1.5645 - val_loss: 3.6646 - val_y1_output_loss: 0.5361 - val_y2_output_loss: 3.2699 - val_y1_output_root_mean_squared_error: 0.7205 - val_y2_output_root_mean_squared_error: 1.7736
# Epoch 83/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.8434 - y1_output_loss: 0.8789 - y2_output_loss: 2.9400 - y1_output_root_mean_squared_error: 0.9408 - y2_output_root_mean_squared_error: 1.7199 - val_loss: 3.1512 - val_y1_output_loss: 0.7086 - val_y2_output_loss: 2.4921 - val_y1_output_root_mean_squared_error: 0.8435 - val_y2_output_root_mean_squared_error: 1.5620
# Epoch 84/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.1101 - y1_output_loss: 0.9086 - y2_output_loss: 3.1739 - y1_output_root_mean_squared_error: 0.9553 - y2_output_root_mean_squared_error: 1.7882 - val_loss: 6.1430 - val_y1_output_loss: 0.7644 - val_y2_output_loss: 5.5580 - val_y1_output_root_mean_squared_error: 0.8463 - val_y2_output_root_mean_squared_error: 2.3295
# Epoch 85/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.0639 - y1_output_loss: 0.9822 - y2_output_loss: 3.0554 - y1_output_root_mean_squared_error: 0.9924 - y2_output_root_mean_squared_error: 1.7548 - val_loss: 2.6828 - val_y1_output_loss: 0.4723 - val_y2_output_loss: 2.3264 - val_y1_output_root_mean_squared_error: 0.6875 - val_y2_output_root_mean_squared_error: 1.4867
# Epoch 86/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.5992 - y1_output_loss: 0.9028 - y2_output_loss: 2.7016 - y1_output_root_mean_squared_error: 0.9417 - y2_output_root_mean_squared_error: 1.6469 - val_loss: 9.7214 - val_y1_output_loss: 3.6733 - val_y2_output_loss: 6.1395 - val_y1_output_root_mean_squared_error: 1.9011 - val_y2_output_root_mean_squared_error: 2.4712
# Epoch 87/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.1965 - y1_output_loss: 1.1597 - y2_output_loss: 3.0239 - y1_output_root_mean_squared_error: 1.0796 - y2_output_root_mean_squared_error: 1.7409 - val_loss: 4.0354 - val_y1_output_loss: 1.0939 - val_y2_output_loss: 3.0154 - val_y1_output_root_mean_squared_error: 1.0643 - val_y2_output_root_mean_squared_error: 1.7037
# Epoch 88/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.3205 - y1_output_loss: 0.7531 - y2_output_loss: 2.5986 - y1_output_root_mean_squared_error: 0.8707 - y2_output_root_mean_squared_error: 1.6008 - val_loss: 7.2094 - val_y1_output_loss: 1.4139 - val_y2_output_loss: 5.9399 - val_y1_output_root_mean_squared_error: 1.2081 - val_y2_output_root_mean_squared_error: 2.3979
# Epoch 89/500
# 614/614 [==============================] - 0s 157us/sample - loss: 9.7693 - y1_output_loss: 2.8804 - y2_output_loss: 6.8600 - y1_output_root_mean_squared_error: 1.7034 - y2_output_root_mean_squared_error: 2.6207 - val_loss: 5.2779 - val_y1_output_loss: 1.3986 - val_y2_output_loss: 3.8613 - val_y1_output_root_mean_squared_error: 1.1985 - val_y2_output_root_mean_squared_error: 1.9600
# Epoch 90/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.6718 - y1_output_loss: 0.8056 - y2_output_loss: 2.8564 - y1_output_root_mean_squared_error: 0.8986 - y2_output_root_mean_squared_error: 1.6924 - val_loss: 2.6181 - val_y1_output_loss: 0.4770 - val_y2_output_loss: 2.2474 - val_y1_output_root_mean_squared_error: 0.6770 - val_y2_output_root_mean_squared_error: 1.4696
# Epoch 91/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.9114 - y1_output_loss: 0.7214 - y2_output_loss: 2.1688 - y1_output_root_mean_squared_error: 0.8533 - y2_output_root_mean_squared_error: 1.4776 - val_loss: 3.2102 - val_y1_output_loss: 0.6450 - val_y2_output_loss: 2.6583 - val_y1_output_root_mean_squared_error: 0.8032 - val_y2_output_root_mean_squared_error: 1.6016
# Epoch 92/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.3971 - y1_output_loss: 0.9088 - y2_output_loss: 2.4675 - y1_output_root_mean_squared_error: 0.9524 - y2_output_root_mean_squared_error: 1.5780 - val_loss: 4.4988 - val_y1_output_loss: 1.2784 - val_y2_output_loss: 3.3914 - val_y1_output_root_mean_squared_error: 1.1143 - val_y2_output_root_mean_squared_error: 1.8047
# Epoch 93/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.0417 - y1_output_loss: 0.6801 - y2_output_loss: 2.3578 - y1_output_root_mean_squared_error: 0.8278 - y2_output_root_mean_squared_error: 1.5351 - val_loss: 3.9205 - val_y1_output_loss: 0.5330 - val_y2_output_loss: 3.5022 - val_y1_output_root_mean_squared_error: 0.7377 - val_y2_output_root_mean_squared_error: 1.8375
# Epoch 94/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.0298 - y1_output_loss: 0.6355 - y2_output_loss: 2.3979 - y1_output_root_mean_squared_error: 0.7952 - y2_output_root_mean_squared_error: 1.5484 - val_loss: 8.3392 - val_y1_output_loss: 2.1233 - val_y2_output_loss: 6.2481 - val_y1_output_root_mean_squared_error: 1.4779 - val_y2_output_root_mean_squared_error: 2.4809
# Epoch 95/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.8623 - y1_output_loss: 0.6902 - y2_output_loss: 2.1618 - y1_output_root_mean_squared_error: 0.8334 - y2_output_root_mean_squared_error: 1.4724 - val_loss: 2.8929 - val_y1_output_loss: 0.3816 - val_y2_output_loss: 2.6593 - val_y1_output_root_mean_squared_error: 0.6136 - val_y2_output_root_mean_squared_error: 1.5863
# Epoch 96/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.2518 - y1_output_loss: 0.5522 - y2_output_loss: 1.7085 - y1_output_root_mean_squared_error: 0.7428 - y2_output_root_mean_squared_error: 1.3039 - val_loss: 4.0591 - val_y1_output_loss: 1.1217 - val_y2_output_loss: 3.0440 - val_y1_output_root_mean_squared_error: 1.0653 - val_y2_output_root_mean_squared_error: 1.7101
# Epoch 97/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.8852 - y1_output_loss: 0.5764 - y2_output_loss: 2.2997 - y1_output_root_mean_squared_error: 0.7616 - y2_output_root_mean_squared_error: 1.5183 - val_loss: 3.1568 - val_y1_output_loss: 0.7061 - val_y2_output_loss: 2.6218 - val_y1_output_root_mean_squared_error: 0.8323 - val_y2_output_root_mean_squared_error: 1.5698
# Epoch 98/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.3566 - y1_output_loss: 0.7590 - y2_output_loss: 2.5742 - y1_output_root_mean_squared_error: 0.8749 - y2_output_root_mean_squared_error: 1.6097 - val_loss: 3.2185 - val_y1_output_loss: 0.6405 - val_y2_output_loss: 2.7215 - val_y1_output_root_mean_squared_error: 0.7801 - val_y2_output_root_mean_squared_error: 1.6155
# Epoch 99/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.0781 - y1_output_loss: 0.6993 - y2_output_loss: 2.4104 - y1_output_root_mean_squared_error: 0.8392 - y2_output_root_mean_squared_error: 1.5407 - val_loss: 2.7609 - val_y1_output_loss: 0.6389 - val_y2_output_loss: 2.1840 - val_y1_output_root_mean_squared_error: 0.7936 - val_y2_output_root_mean_squared_error: 1.4598
# Epoch 100/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.0392 - y1_output_loss: 0.6580 - y2_output_loss: 2.3606 - y1_output_root_mean_squared_error: 0.8126 - y2_output_root_mean_squared_error: 1.5424 - val_loss: 2.3371 - val_y1_output_loss: 0.4295 - val_y2_output_loss: 2.0222 - val_y1_output_root_mean_squared_error: 0.6369 - val_y2_output_root_mean_squared_error: 1.3898
# Epoch 101/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.6618 - y1_output_loss: 0.8498 - y2_output_loss: 2.8299 - y1_output_root_mean_squared_error: 0.9167 - y2_output_root_mean_squared_error: 1.6797 - val_loss: 6.3944 - val_y1_output_loss: 2.4935 - val_y2_output_loss: 3.9795 - val_y1_output_root_mean_squared_error: 1.5987 - val_y2_output_root_mean_squared_error: 1.9593
# Epoch 102/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.4652 - y1_output_loss: 0.7923 - y2_output_loss: 2.6667 - y1_output_root_mean_squared_error: 0.8915 - y2_output_root_mean_squared_error: 1.6341 - val_loss: 2.7905 - val_y1_output_loss: 0.4008 - val_y2_output_loss: 2.5130 - val_y1_output_root_mean_squared_error: 0.6390 - val_y2_output_root_mean_squared_error: 1.5434
# Epoch 103/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.4286 - y1_output_loss: 0.4947 - y2_output_loss: 1.9282 - y1_output_root_mean_squared_error: 0.7031 - y2_output_root_mean_squared_error: 1.3908 - val_loss: 3.7128 - val_y1_output_loss: 0.5621 - val_y2_output_loss: 3.2405 - val_y1_output_root_mean_squared_error: 0.7567 - val_y2_output_root_mean_squared_error: 1.7721
# Epoch 104/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.9530 - y1_output_loss: 0.5808 - y2_output_loss: 2.3848 - y1_output_root_mean_squared_error: 0.7623 - y2_output_root_mean_squared_error: 1.5401 - val_loss: 5.2246 - val_y1_output_loss: 0.7716 - val_y2_output_loss: 4.6524 - val_y1_output_root_mean_squared_error: 0.8557 - val_y2_output_root_mean_squared_error: 2.1195
# Epoch 105/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.4321 - y1_output_loss: 0.5218 - y2_output_loss: 1.9638 - y1_output_root_mean_squared_error: 0.7251 - y2_output_root_mean_squared_error: 1.3807 - val_loss: 7.5406 - val_y1_output_loss: 0.9730 - val_y2_output_loss: 6.6837 - val_y1_output_root_mean_squared_error: 1.0020 - val_y2_output_root_mean_squared_error: 2.5567
# Epoch 106/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.6360 - y1_output_loss: 0.6451 - y2_output_loss: 1.9852 - y1_output_root_mean_squared_error: 0.8057 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 3.1049 - val_y1_output_loss: 0.7111 - val_y2_output_loss: 2.4842 - val_y1_output_root_mean_squared_error: 0.8559 - val_y2_output_root_mean_squared_error: 1.5403
# Epoch 107/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.1229 - y1_output_loss: 0.7151 - y2_output_loss: 2.3906 - y1_output_root_mean_squared_error: 0.8455 - y2_output_root_mean_squared_error: 1.5518 - val_loss: 5.0977 - val_y1_output_loss: 0.6482 - val_y2_output_loss: 4.6005 - val_y1_output_root_mean_squared_error: 0.7845 - val_y2_output_root_mean_squared_error: 2.1171
# Epoch 108/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.1658 - y1_output_loss: 0.4412 - y2_output_loss: 1.7383 - y1_output_root_mean_squared_error: 0.6657 - y2_output_root_mean_squared_error: 1.3125 - val_loss: 4.6020 - val_y1_output_loss: 0.5976 - val_y2_output_loss: 4.1447 - val_y1_output_root_mean_squared_error: 0.7788 - val_y2_output_root_mean_squared_error: 1.9989
# Epoch 109/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.2633 - y1_output_loss: 0.5236 - y2_output_loss: 1.7251 - y1_output_root_mean_squared_error: 0.7262 - y2_output_root_mean_squared_error: 1.3176 - val_loss: 2.4101 - val_y1_output_loss: 0.3666 - val_y2_output_loss: 2.1616 - val_y1_output_root_mean_squared_error: 0.6002 - val_y2_output_root_mean_squared_error: 1.4317
# Epoch 110/500
# 614/614 [==============================] - 0s 157us/sample - loss: 10.4987 - y1_output_loss: 3.3757 - y2_output_loss: 7.0356 - y1_output_root_mean_squared_error: 1.8444 - y2_output_root_mean_squared_error: 2.6640 - val_loss: 3.1490 - val_y1_output_loss: 0.5834 - val_y2_output_loss: 2.6447 - val_y1_output_root_mean_squared_error: 0.7702 - val_y2_output_root_mean_squared_error: 1.5987
# Epoch 111/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.9646 - y1_output_loss: 0.6583 - y2_output_loss: 2.3453 - y1_output_root_mean_squared_error: 0.8133 - y2_output_root_mean_squared_error: 1.5176 - val_loss: 6.4247 - val_y1_output_loss: 1.1283 - val_y2_output_loss: 5.2882 - val_y1_output_root_mean_squared_error: 1.0765 - val_y2_output_root_mean_squared_error: 2.2948
# Epoch 112/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.6197 - y1_output_loss: 0.6043 - y2_output_loss: 2.0243 - y1_output_root_mean_squared_error: 0.7778 - y2_output_root_mean_squared_error: 1.4194 - val_loss: 5.8415 - val_y1_output_loss: 0.7364 - val_y2_output_loss: 5.1796 - val_y1_output_root_mean_squared_error: 0.8647 - val_y2_output_root_mean_squared_error: 2.2569
# Epoch 113/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.4338 - y1_output_loss: 0.5008 - y2_output_loss: 1.9155 - y1_output_root_mean_squared_error: 0.7107 - y2_output_root_mean_squared_error: 1.3888 - val_loss: 2.2609 - val_y1_output_loss: 0.4020 - val_y2_output_loss: 1.9550 - val_y1_output_root_mean_squared_error: 0.6326 - val_y2_output_root_mean_squared_error: 1.3641
# Epoch 114/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.2160 - y1_output_loss: 0.5223 - y2_output_loss: 1.6754 - y1_output_root_mean_squared_error: 0.7252 - y2_output_root_mean_squared_error: 1.3000 - val_loss: 2.2516 - val_y1_output_loss: 0.4256 - val_y2_output_loss: 1.9761 - val_y1_output_root_mean_squared_error: 0.6535 - val_y2_output_root_mean_squared_error: 1.3508
# Epoch 115/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.4224 - y1_output_loss: 1.2833 - y2_output_loss: 4.1104 - y1_output_root_mean_squared_error: 1.1328 - y2_output_root_mean_squared_error: 2.0345 - val_loss: 3.3835 - val_y1_output_loss: 0.7714 - val_y2_output_loss: 2.6658 - val_y1_output_root_mean_squared_error: 0.8756 - val_y2_output_root_mean_squared_error: 1.6176
# Epoch 116/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4030 - y1_output_loss: 0.5093 - y2_output_loss: 1.9044 - y1_output_root_mean_squared_error: 0.7122 - y2_output_root_mean_squared_error: 1.3769 - val_loss: 2.5284 - val_y1_output_loss: 0.5405 - val_y2_output_loss: 2.0900 - val_y1_output_root_mean_squared_error: 0.7246 - val_y2_output_root_mean_squared_error: 1.4154
# Epoch 117/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.7860 - y1_output_loss: 0.6512 - y2_output_loss: 2.1243 - y1_output_root_mean_squared_error: 0.8104 - y2_output_root_mean_squared_error: 1.4592 - val_loss: 2.4082 - val_y1_output_loss: 0.3499 - val_y2_output_loss: 2.1646 - val_y1_output_root_mean_squared_error: 0.5869 - val_y2_output_root_mean_squared_error: 1.4366
# Epoch 118/500
# 614/614 [==============================] - 0s 160us/sample - loss: 1.8535 - y1_output_loss: 0.4335 - y2_output_loss: 1.4615 - y1_output_root_mean_squared_error: 0.6542 - y2_output_root_mean_squared_error: 1.1940 - val_loss: 12.4589 - val_y1_output_loss: 2.4131 - val_y2_output_loss: 10.1639 - val_y1_output_root_mean_squared_error: 1.5757 - val_y2_output_root_mean_squared_error: 3.1585
# Epoch 119/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.3097 - y1_output_loss: 0.5248 - y2_output_loss: 1.7685 - y1_output_root_mean_squared_error: 0.7274 - y2_output_root_mean_squared_error: 1.3344 - val_loss: 2.4257 - val_y1_output_loss: 0.4877 - val_y2_output_loss: 2.0674 - val_y1_output_root_mean_squared_error: 0.7056 - val_y2_output_root_mean_squared_error: 1.3885
# Epoch 120/500
# 614/614 [==============================] - 0s 153us/sample - loss: 1.9752 - y1_output_loss: 0.3822 - y2_output_loss: 1.5966 - y1_output_root_mean_squared_error: 0.6200 - y2_output_root_mean_squared_error: 1.2613 - val_loss: 2.3688 - val_y1_output_loss: 0.5814 - val_y2_output_loss: 1.9250 - val_y1_output_root_mean_squared_error: 0.7406 - val_y2_output_root_mean_squared_error: 1.3492
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.6046 - y1_output_loss: 0.1528 - y2_output_loss: 0.4533 - y1_output_root_mean_squared_error: 0.3880 - y2_output_root_mean_squared_error: 0.6738 - val_loss: 1.8398 - val_y1_output_loss: 0.5446 - val_y2_output_loss: 1.2674 - val_y1_output_root_mean_squared_error: 0.7513 - val_y2_output_root_mean_squared_error: 1.1293
# Epoch 462/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5693 - y1_output_loss: 0.1586 - y2_output_loss: 0.4069 - y1_output_root_mean_squared_error: 0.3986 - y2_output_root_mean_squared_error: 0.6407 - val_loss: 0.9722 - val_y1_output_loss: 0.1880 - val_y2_output_loss: 0.7847 - val_y1_output_root_mean_squared_error: 0.4276 - val_y2_output_root_mean_squared_error: 0.8885
# Epoch 463/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4929 - y1_output_loss: 0.1173 - y2_output_loss: 0.3972 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.6135 - val_loss: 4.6361 - val_y1_output_loss: 0.3689 - val_y2_output_loss: 4.4986 - val_y1_output_root_mean_squared_error: 0.5767 - val_y2_output_root_mean_squared_error: 2.0745
# Epoch 464/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5126 - y1_output_loss: 0.1043 - y2_output_loss: 0.4052 - y1_output_root_mean_squared_error: 0.3235 - y2_output_root_mean_squared_error: 0.6387 - val_loss: 1.2301 - val_y1_output_loss: 0.2433 - val_y2_output_loss: 0.9821 - val_y1_output_root_mean_squared_error: 0.4982 - val_y2_output_root_mean_squared_error: 0.9909
# Epoch 465/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3936 - y1_output_loss: 0.1092 - y2_output_loss: 0.2837 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.5323 - val_loss: 0.8375 - val_y1_output_loss: 0.1869 - val_y2_output_loss: 0.6960 - val_y1_output_root_mean_squared_error: 0.4166 - val_y2_output_root_mean_squared_error: 0.8148
# Epoch 466/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4502 - y1_output_loss: 0.1297 - y2_output_loss: 0.3184 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5653 - val_loss: 0.8534 - val_y1_output_loss: 0.1720 - val_y2_output_loss: 0.7101 - val_y1_output_root_mean_squared_error: 0.4020 - val_y2_output_root_mean_squared_error: 0.8318
# Epoch 467/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3952 - y1_output_loss: 0.1184 - y2_output_loss: 0.2764 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 0.9410 - val_y1_output_loss: 0.1957 - val_y2_output_loss: 0.7601 - val_y1_output_root_mean_squared_error: 0.4309 - val_y2_output_root_mean_squared_error: 0.8691
# Epoch 468/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4570 - y1_output_loss: 0.1275 - y2_output_loss: 0.3280 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5738 - val_loss: 0.8328 - val_y1_output_loss: 0.1690 - val_y2_output_loss: 0.6797 - val_y1_output_root_mean_squared_error: 0.3975 - val_y2_output_root_mean_squared_error: 0.8215
# Epoch 469/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3736 - y1_output_loss: 0.1093 - y2_output_loss: 0.2708 - y1_output_root_mean_squared_error: 0.3299 - y2_output_root_mean_squared_error: 0.5146 - val_loss: 1.2039 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 1.0932 - val_y1_output_root_mean_squared_error: 0.4060 - val_y2_output_root_mean_squared_error: 1.0194
# Epoch 470/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.6154 - y1_output_loss: 0.1476 - y2_output_loss: 0.4634 - y1_output_root_mean_squared_error: 0.3848 - y2_output_root_mean_squared_error: 0.6836 - val_loss: 0.8094 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.6385 - val_y1_output_root_mean_squared_error: 0.4122 - val_y2_output_root_mean_squared_error: 0.7997
# Epoch 471/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5487 - y1_output_loss: 0.1496 - y2_output_loss: 0.3951 - y1_output_root_mean_squared_error: 0.3879 - y2_output_root_mean_squared_error: 0.6311 - val_loss: 0.7849 - val_y1_output_loss: 0.1582 - val_y2_output_loss: 0.6293 - val_y1_output_root_mean_squared_error: 0.3917 - val_y2_output_root_mean_squared_error: 0.7946
# Epoch 472/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5509 - y1_output_loss: 0.1655 - y2_output_loss: 0.3807 - y1_output_root_mean_squared_error: 0.4085 - y2_output_root_mean_squared_error: 0.6197 - val_loss: 0.8072 - val_y1_output_loss: 0.1854 - val_y2_output_loss: 0.6290 - val_y1_output_root_mean_squared_error: 0.4311 - val_y2_output_root_mean_squared_error: 0.7882
# Epoch 473/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4253 - y1_output_loss: 0.1157 - y2_output_loss: 0.3102 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5574 - val_loss: 1.1488 - val_y1_output_loss: 0.2043 - val_y2_output_loss: 0.9824 - val_y1_output_root_mean_squared_error: 0.4434 - val_y2_output_root_mean_squared_error: 0.9758
# Epoch 474/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5130 - y1_output_loss: 0.1339 - y2_output_loss: 0.3831 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.6157 - val_loss: 2.0985 - val_y1_output_loss: 0.2273 - val_y2_output_loss: 2.0320 - val_y1_output_root_mean_squared_error: 0.4555 - val_y2_output_root_mean_squared_error: 1.3751
# Epoch 475/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.6054 - y1_output_loss: 0.1506 - y2_output_loss: 0.4540 - y1_output_root_mean_squared_error: 0.3888 - y2_output_root_mean_squared_error: 0.6740 - val_loss: 1.1661 - val_y1_output_loss: 0.2160 - val_y2_output_loss: 1.0275 - val_y1_output_root_mean_squared_error: 0.4443 - val_y2_output_root_mean_squared_error: 0.9843
# Epoch 476/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4901 - y1_output_loss: 0.1412 - y2_output_loss: 0.3458 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5902 - val_loss: 0.8566 - val_y1_output_loss: 0.1976 - val_y2_output_loss: 0.6862 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.8187
# Epoch 477/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.5178 - y1_output_loss: 0.1404 - y2_output_loss: 0.3755 - y1_output_root_mean_squared_error: 0.3759 - y2_output_root_mean_squared_error: 0.6136 - val_loss: 1.0370 - val_y1_output_loss: 0.2059 - val_y2_output_loss: 0.8675 - val_y1_output_root_mean_squared_error: 0.4307 - val_y2_output_root_mean_squared_error: 0.9227
# Epoch 478/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4988 - y1_output_loss: 0.1250 - y2_output_loss: 0.3710 - y1_output_root_mean_squared_error: 0.3542 - y2_output_root_mean_squared_error: 0.6110 - val_loss: 0.8236 - val_y1_output_loss: 0.2044 - val_y2_output_loss: 0.6257 - val_y1_output_root_mean_squared_error: 0.4490 - val_y2_output_root_mean_squared_error: 0.7887
# Epoch 479/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4936 - y1_output_loss: 0.1341 - y2_output_loss: 0.3598 - y1_output_root_mean_squared_error: 0.3644 - y2_output_root_mean_squared_error: 0.6007 - val_loss: 1.7021 - val_y1_output_loss: 0.4077 - val_y2_output_loss: 1.2691 - val_y1_output_root_mean_squared_error: 0.6465 - val_y2_output_root_mean_squared_error: 1.1332
# Epoch 480/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3762 - y1_output_loss: 0.1148 - y2_output_loss: 0.2583 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.7606 - val_y1_output_loss: 0.1673 - val_y2_output_loss: 0.6222 - val_y1_output_root_mean_squared_error: 0.3945 - val_y2_output_root_mean_squared_error: 0.7778
# Epoch 481/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3508 - y1_output_loss: 0.1061 - y2_output_loss: 0.2438 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4942 - val_loss: 0.9080 - val_y1_output_loss: 0.2018 - val_y2_output_loss: 0.7155 - val_y1_output_root_mean_squared_error: 0.4430 - val_y2_output_root_mean_squared_error: 0.8436
# Epoch 482/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3332 - y1_output_loss: 0.1116 - y2_output_loss: 0.2277 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.4720 - val_loss: 1.5271 - val_y1_output_loss: 0.1797 - val_y2_output_loss: 1.4263 - val_y1_output_root_mean_squared_error: 0.4061 - val_y2_output_root_mean_squared_error: 1.1671
# Epoch 483/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3846 - y1_output_loss: 0.1110 - y2_output_loss: 0.2703 - y1_output_root_mean_squared_error: 0.3344 - y2_output_root_mean_squared_error: 0.5222 - val_loss: 0.7022 - val_y1_output_loss: 0.1665 - val_y2_output_loss: 0.5506 - val_y1_output_root_mean_squared_error: 0.3943 - val_y2_output_root_mean_squared_error: 0.7394
# Epoch 484/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3295 - y1_output_loss: 0.1112 - y2_output_loss: 0.2174 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4671 - val_loss: 0.9050 - val_y1_output_loss: 0.2202 - val_y2_output_loss: 0.7098 - val_y1_output_root_mean_squared_error: 0.4583 - val_y2_output_root_mean_squared_error: 0.8336
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.0156 - y1_output_loss: 0.2421 - y2_output_loss: 0.7653 - y1_output_root_mean_squared_error: 0.4930 - y2_output_root_mean_squared_error: 0.8790 - val_loss: 0.8888 - val_y1_output_loss: 0.1949 - val_y2_output_loss: 0.7314 - val_y1_output_root_mean_squared_error: 0.4241 - val_y2_output_root_mean_squared_error: 0.8420
# Epoch 486/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3944 - y1_output_loss: 0.1126 - y2_output_loss: 0.2798 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.5311 - val_loss: 0.7837 - val_y1_output_loss: 0.1965 - val_y2_output_loss: 0.6076 - val_y1_output_root_mean_squared_error: 0.4230 - val_y2_output_root_mean_squared_error: 0.7777
# Epoch 487/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3752 - y1_output_loss: 0.1104 - y2_output_loss: 0.2645 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5140 - val_loss: 1.0339 - val_y1_output_loss: 0.1707 - val_y2_output_loss: 0.8795 - val_y1_output_root_mean_squared_error: 0.4028 - val_y2_output_root_mean_squared_error: 0.9336
# Epoch 488/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4959 - y1_output_loss: 0.1594 - y2_output_loss: 0.3336 - y1_output_root_mean_squared_error: 0.4001 - y2_output_root_mean_squared_error: 0.5795 - val_loss: 0.7759 - val_y1_output_loss: 0.1870 - val_y2_output_loss: 0.6075 - val_y1_output_root_mean_squared_error: 0.4113 - val_y2_output_root_mean_squared_error: 0.7789
# Epoch 489/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3301 - y1_output_loss: 0.1071 - y2_output_loss: 0.2209 - y1_output_root_mean_squared_error: 0.3278 - y2_output_root_mean_squared_error: 0.4719 - val_loss: 0.8778 - val_y1_output_loss: 0.1593 - val_y2_output_loss: 0.7542 - val_y1_output_root_mean_squared_error: 0.3851 - val_y2_output_root_mean_squared_error: 0.8541
# Epoch 490/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4888 - y1_output_loss: 0.1456 - y2_output_loss: 0.3415 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.5855 - val_loss: 0.9289 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 0.7520 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.8683
# Epoch 491/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4339 - y1_output_loss: 0.1217 - y2_output_loss: 0.3103 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5584 - val_loss: 0.8964 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.7293 - val_y1_output_root_mean_squared_error: 0.4346 - val_y2_output_root_mean_squared_error: 0.8412
# Epoch 492/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4921 - y1_output_loss: 0.1350 - y2_output_loss: 0.3532 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.5969 - val_loss: 0.8970 - val_y1_output_loss: 0.1962 - val_y2_output_loss: 0.7202 - val_y1_output_root_mean_squared_error: 0.4298 - val_y2_output_root_mean_squared_error: 0.8440
# Epoch 493/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5301 - y1_output_loss: 0.1307 - y2_output_loss: 0.4031 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.6329 - val_loss: 1.6132 - val_y1_output_loss: 0.3279 - val_y2_output_loss: 1.4001 - val_y1_output_root_mean_squared_error: 0.5428 - val_y2_output_root_mean_squared_error: 1.1483
# Epoch 494/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3903 - y1_output_loss: 0.1203 - y2_output_loss: 0.2679 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5185 - val_loss: 0.8104 - val_y1_output_loss: 0.1813 - val_y2_output_loss: 0.6613 - val_y1_output_root_mean_squared_error: 0.4065 - val_y2_output_root_mean_squared_error: 0.8032
# Epoch 495/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3373 - y1_output_loss: 0.1106 - y2_output_loss: 0.2258 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.4753 - val_loss: 0.7727 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 0.6151 - val_y1_output_root_mean_squared_error: 0.3992 - val_y2_output_root_mean_squared_error: 0.7832
# Epoch 496/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3430 - y1_output_loss: 0.1117 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 0.6990 - val_y1_output_loss: 0.1518 - val_y2_output_loss: 0.5632 - val_y1_output_root_mean_squared_error: 0.3804 - val_y2_output_root_mean_squared_error: 0.7445
# Epoch 497/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5056 - y1_output_loss: 0.1329 - y2_output_loss: 0.3689 - y1_output_root_mean_squared_error: 0.3656 - y2_output_root_mean_squared_error: 0.6098 - val_loss: 0.8787 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 0.6753 - val_y1_output_root_mean_squared_error: 0.4371 - val_y2_output_root_mean_squared_error: 0.8292
# Epoch 498/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4100 - y1_output_loss: 0.1193 - y2_output_loss: 0.2930 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5385 - val_loss: 1.8208 - val_y1_output_loss: 0.3868 - val_y2_output_loss: 1.4338 - val_y1_output_root_mean_squared_error: 0.6180 - val_y2_output_root_mean_squared_error: 1.1995
# Epoch 499/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4703 - y1_output_loss: 0.1477 - y2_output_loss: 0.3387 - y1_output_root_mean_squared_error: 0.3852 - y2_output_root_mean_squared_error: 0.5674 - val_loss: 1.9749 - val_y1_output_loss: 0.1834 - val_y2_output_loss: 1.7644 - val_y1_output_root_mean_squared_error: 0.4226 - val_y2_output_root_mean_squared_error: 1.3403
# Epoch 500/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4492 - y1_output_loss: 0.1213 - y2_output_loss: 0.3245 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5723 - val_loss: 0.7446 - val_y1_output_loss: 0.1808 - val_y2_output_loss: 0.5651 - val_y1_output_root_mean_squared_error: 0.4243 - val_y2_output_root_mean_squared_error: 0.7514

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 39us/sample - loss: 0.7446 - y1_output_loss: 0.1821 - y2_output_loss: 0.5802 - y1_output_root_mean_squared_error: 0.4243 - y2_output_root_mean_squared_error: 0.7514
# Loss = 0.7445518552482903, Y1_loss = 0.18212774395942688, Y1_mse = 0.4242928624153137, Y2_loss = 0.5801690816879272, Y2_mse = 0.7513504028320312

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
